# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mouse_results = pd.merge(mouse_metadata, study_results, how="outer", on="Mouse ID")

# Display the data table for preview
mouse_results.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
mouse_results.describe()
# Out:
#         Age_months   Weight (g)    Timepoint  Tumor Volume (mm3)  \
# count  1893.000000  1893.000000  1893.000000         1893.000000
# mean     12.814580    25.662441    19.572108           50.448381
# std       7.189592     3.921622    14.079460            8.894722
# min       1.000000    15.000000     0.000000           22.050126
# 25%       7.000000    25.000000     5.000000           45.000000
# 50%      13.000000    27.000000    20.000000           48.951474
# 75%      20.000000    29.000000    30.000000           56.292200
# max      24.000000    30.000000    45.000000           78.567014
#
#        Metastatic Sites
# count       1893.000000
# mean           1.021659
# std            1.137974
# min            0.000000
# 25%            0.000000
# 50%            1.000000
# 75%            2.000000
# max            4.000000

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
mouse_duplicates = mouse_results
mouse_duplicates["Duplicate"] = mouse_results.duplicated(subset=["Mouse ID", "Timepoint"])
mouse_duplicates["Duplicate"].value_counts()
# Out:
# False    1888
# True        5
# Name: Duplicate, dtype: int64

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicates = mouse_duplicates.loc[mouse_duplicates["Duplicate"] == True]
duplicates
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites  Duplicate
# 909           45.000000                 0       True
# 911           47.570392                 0       True
# 913           49.880528                 0       True
# 915           53.442020                 0       True
# 917           54.657650                 1       True

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_mouse_results = mouse_results.drop_duplicates(subset=["Mouse ID", "Timepoint"])

# %%
# Checking the number of mice in the clean DataFrame.
clean_mouse_results.describe()
# Out:
#         Age_months   Weight (g)    Timepoint  Tumor Volume (mm3)  \
# count  1888.000000  1888.000000  1888.000000         1888.000000
# mean     12.792903    25.661547    19.597458           50.449276
# std       7.186737     3.926776    14.084762            8.904565
# min       1.000000    15.000000     0.000000           22.050126
# 25%       7.000000    25.000000     5.000000           45.000000
# 50%      13.000000    27.000000    20.000000           48.951421
# 75%      20.000000    29.000000    30.000000           56.324075
# max      24.000000    30.000000    45.000000           78.567014
#
#        Metastatic Sites
# count       1888.000000
# mean           1.023835
# std            1.138507
# min            0.000000
# 25%            0.000000
# 50%            1.000000
# 75%            2.000000
# max            4.000000

# %%
clean_mouse_results["Drug Regimen"].value_counts()
# Out:
# Capomulin    230
# Ramicane     228
# Ketapril     188
# Naftisol     186
# Zoniferol    182
# Stelasyn     181
# Placebo      181
# Infubinol    178
# Ceftamin     178
# Propriva     156
# Name: Drug Regimen, dtype: int64

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume.
tumor = clean_mouse_results[["Drug Regimen", "Tumor Volume (mm3)"]]
tumor_mean = tumor.groupby(["Drug Regimen"]).mean()
tumor_median = tumor.groupby(["Drug Regimen"]).median()
tumor_variance = tumor.groupby(["Drug Regimen"]).var()
tumor_sd = tumor.groupby(["Drug Regimen"]).std()
tumor_sem = tumor.groupby(["Drug Regimen"]).sem()

# Assemble the resulting series into a single summary dataframe
mm_merge = pd.merge(tumor_mean, tumor_median, on="Drug Regimen")
mm = mm_merge.rename(columns={"Tumor Volume (mm3)_x":"Average Volume", "Tumor Volume (mm3)_y":"Median Volume"})
mmv_merge = pd.merge(mm, tumor_variance, on="Drug Regimen")
mmv = mmv_merge.rename(columns={"Tumor Volume (mm3)":"Volume Variance"})
mmvs_merge = pd.merge(mmv, tumor_sd, on="Drug Regimen")
mmvs = mmvs_merge.rename(columns={"Tumor Volume (mm3)":"Volume Standard Deviation"})
mmvss_merge = pd.merge(mmv, tumor_sem, on="Drug Regimen")
mmvss = mmvss_merge.rename(columns={"Tumor Volume (mm3)":"Volume Standard Error"})
mmvss.head()
# Out:
#               Average Volume  Median Volume  Volume Variance  \
# Drug Regimen
# Capomulin          40.675741      41.557809        24.947764
# Ceftamin           52.591172      51.776157        39.290177
# Infubinol          52.884795      51.820584        43.128684
# Ketapril           55.235638      53.698743        68.553577
# Naftisol           54.331565      52.509285        66.173479
#
#               Volume Standard Error
# Drug Regimen
# Capomulin                  0.329346
# Ceftamin                   0.469821
# Infubinol                  0.492236
# Ketapril                   0.603860
# Naftisol                   0.596466

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
mmvss_agg = mmvss.aggregate

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.
measure_group = clean_mouse_results["Drug Regimen"].value_counts()
measurements_taken = pd.DataFrame(measure_group)
# measurements_taken = measurements_taken.rename(columns={"Drug Regimen": "Total Count"})

measurements_taken.plot.bar(color="blue")
# Out:
# <AxesSubplot:>

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
measurements_taken = measurements_taken.reset_index()
measurements_taken = measurements_taken.rename(columns={"Drug Regimen": "Total Count", "index": "Drug Regimen"})
measurements_taken
x_axis = measurements_taken["Drug Regimen"]
y_axis = measurements_taken["Total Count"]
plt.bar(x_axis, y_axis, color = "blue")
plt.xticks(rotation='vertical')
plt.title("Total Number of Measurements for Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Total Measurements Taken")
plt.legend("Drug Regimen");

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
ID_sex = clean_mouse_results.drop(columns=["Drug Regimen",
                                          "Age_months",
                                          "Weight (g)",
                                          "Timepoint",
                                          "Tumor Volume (mm3)",
                                          "Metastatic Sites",
                                          "Duplicate"])
ID_sex_group = ID_sex.drop_duplicates().value_counts(["Sex"])
sex_dist = pd.DataFrame(ID_sex_group)

ID_sex_group.plot.pie(y="Sex", autopct="%1.1f")
plt.title("Distribution of Female to Male Mice");

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
amount = [125, 124]
labels = ["Male", "Female"]
colors = ["blue", "orange"]

plt.pie(amount, labels=labels, colors=colors, autopct="%1.1f")
plt.title("Distribution of Female to Male Mice");

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
clean_mouse_results["Drug Regimen"].value_counts()
# Out:
# Capomulin    230
# Ramicane     228
# Ketapril     188
# Naftisol     186
# Zoniferol    182
# Stelasyn     181
# Placebo      181
# Infubinol    178
# Ceftamin     178
# Propriva     156
# Name: Drug Regimen, dtype: int64

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
Cap = clean_mouse_results.loc[clean_mouse_results["Drug Regimen"]=="Capomulin"]
Ram = clean_mouse_results.loc[clean_mouse_results["Drug Regimen"]=="Ramicane"]
Inf = clean_mouse_results.loc[clean_mouse_results["Drug Regimen"]=="Infubinol"]
Ceft = clean_mouse_results.loc[clean_mouse_results["Drug Regimen"]=="Ceft"]

# Start by getting the last (greatest) timepoint for each mouse
last_Cap = Cap.loc[Cap["Timepoint"]==Cap["Timepoint"].max(),:]
last_Ram = Ram.loc[Ram["Timepoint"]==Ram["Timepoint"].max(),:]
last_Inf = Inf.loc[Inf["Timepoint"]==Inf["Timepoint"].max(),:]
last_Ceft = Ceft.loc[Ceft["Timepoint"]==Ceft["Timepoint"].max(),:]

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
last_point = last_Cap.append(Ram, ignore_index=True)
last_point = last_point.append(Inf, ignore_index=True)
last_point = last_point.append(Ceft, ignore_index=True)
last_point
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0       s185    Capomulin  Female           3          17         45
# 1       x401    Capomulin  Female          16          15         45
# 2       m601    Capomulin    Male          22          17         45
# 3       u364    Capomulin    Male          18          17         45
# 4       y793    Capomulin    Male          17          17         45
# ..       ...          ...     ...         ...         ...        ...
# 422     z581    Infubinol  Female          24          25         25
# 423     z581    Infubinol  Female          24          25         30
# 424     z581    Infubinol  Female          24          25         35
# 425     z581    Infubinol  Female          24          25         40
# 426     z581    Infubinol  Female          24          25         45
#
#      Tumor Volume (mm3)  Metastatic Sites  Duplicate
# 0             23.343598                 1      False
# 1             28.484033                 0      False
# 2             28.430964                 1      False
# 3             31.023923                 3      False
# 4             31.896238                 2      False
# ..                  ...               ...        ...
# 422           54.316407                 2      False
# 423           56.286750                 2      False
# 424           58.628399                 3      False
# 425           60.053740                 3      False
# 426           62.754451                 3      False
#
# [427 rows x 9 columns]

# %%
last_Cap
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 19      s185    Capomulin  Female           3          17         45
# 29      x401    Capomulin  Female          16          15         45
# 39      m601    Capomulin    Male          22          17         45
# 104     u364    Capomulin    Male          18          17         45
# 124     y793    Capomulin    Male          17          17         45
# 134     r554    Capomulin  Female           8          17         45
# 144     m957    Capomulin  Female           3          19         45
# 164     t565    Capomulin  Female          20          17         45
# 204     i738    Capomulin  Female          23          20         45
# 224     w914    Capomulin    Male          24          21         45
# 244     g288    Capomulin    Male           3          19         45
# 282     l897    Capomulin    Male          17          19         45
# 299     b742    Capomulin    Male           7          21         45
# 309     b128    Capomulin  Female           9          22         45
# 337     j119    Capomulin  Female           7          23         45
# 350     v923    Capomulin  Female          19          21         45
# 360     g316    Capomulin  Female          22          22         45
# 370     s710    Capomulin  Female           1          23         45
# 380     l509    Capomulin    Male          17          21         45
# 390     r944    Capomulin    Male          12          25         45
# 440     i557    Capomulin  Female           1          24         45
#
#      Tumor Volume (mm3)  Metastatic Sites  Duplicate
# 19            23.343598                 1      False
# 29            28.484033                 0      False
# 39            28.430964                 1      False
# 104           31.023923                 3      False
# 124           31.896238                 2      False
# 134           32.377357                 3      False
# 144           33.329098                 1      False
# 164           34.455298                 0      False
# 204           37.311846                 2      False
# 224           36.041047                 2      False
# 244           37.074024                 1      False
# 282           38.846876                 1      False
# 299           38.939633                 0      False
# 309           38.982878                 2      False
# 337           38.125164                 1      False
# 350           40.658124                 2      False
# 360           40.159220                 2      False
# 370           40.728578                 1      False
# 380           41.483008                 3      False
# 390           41.581521                 2      False
# 440           47.685963                 1      False

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ["Capomulin","Ramicane","Infubinol","Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
cap_tv = []
ram_tv = []
inf_tv = []
ceft_tv = []

cap_tv.append(last_Cap["Tumor Volume (mm3)"])
ram_tv.append(last_Ram["Tumor Volume (mm3)"])
inf_tv.append(last_Inf["Tumor Volume (mm3)"])
ceft_tv.append(last_Ceft["Tumor Volume (mm3)"])


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds
# Out:
# [19     23.343598
#  29     28.484033
#  39     28.430964
#  104    31.023923
#  124    31.896238
#  134    32.377357
#  144    33.329098
#  164    34.455298
#  204    37.311846
#  224    36.041047
#  244    37.074024
#  282    38.846876
#  299    38.939633
#  309    38.982878
#  337    38.125164
#  350    40.658124
#  360    40.159220
#  370    40.728578
#  380    41.483008
#  390    41.581521
#  440    47.685963
#  Name: Tumor Volume (mm3), dtype: float64]

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
only_cap = mouse_results.loc[mouse_results["Drug Regimen"]=="Capomulin",:]

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
x_axis = mouse_cap["Timepoint"]
y_axis = mouse_cap["Tumor Volume (mm3)"]
plt.plot(x_axis, y_axis)
plt.title("Tumor Volume Over Time for Mouse Treated with Capomulin")
plt.xlabel("Timepoint")
plt.ylabel("Tumor Volume (mm3)");

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
id_tumor = only_cap[["Mouse ID", "Tumor Volume (mm3)"]]
id_tumor_mean = id_tumor.groupby(["Mouse ID"]).mean()


id_tumor_drop = only_cap.drop_duplicates(subset=["Mouse ID"])
id_tumor_drop = id_tumor_drop[["Mouse ID", "Weight (g)"]]

cap_tumor = pd.merge(id_tumor_drop, id_tumor_mean, on="Mouse ID")
cap_tumor

x_axis = cap_tumor["Tumor Volume (mm3)"]
y_axis = cap_tumor["Weight (g)"]

plt.scatter(x_axis, y_axis, marker="o", facecolors="blue");
plt.title("Average Tumor Volume vs. Weight for Mice Treated with Capomulin")
plt.xlabel("Average Tumor Volume (mm3)");
plt.ylabel("Mouse Weight (g)");

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis,y_axis, marker="o", facecolors="blue");
plt.plot(x_axis,regress_values,"r-");
plt.annotate(line_eq,(40, 16), fontsize=15,color="red");
plt.title("Average Tumor Volume vs. Weight for Mice Treated with Capomulin")
plt.xlabel("Average Tumor Volume (mm3)")
plt.ylabel("Mouse Weight (g)")
print(f"The r-squared is: {rvalue**2}");
# Out:
# The r-squared is: 0.7088568047708721
